# %% [markdown]
# # Import Ports
# This example shows how to import ports. In this example, we are going to
#
# - Download an example board
# - Create a configuration file
#   - Add a circuit port between two nets
#   - Add a circuit port between two pins
#   - Add a circuit port between two pin groups
#   - Add a circuit port between two coordinates
#   - Add a coax port
#   - Add a port reference to the nearest pin
#   - Add distributed ports
# - Import the configuration file

# %% [markdown]
# ## Import the required packages

# %%
import json
from pathlib import Path
import tempfile

from ansys.aedt.core.downloads import download_file

from pyedb import Edb

AEDT_VERSION = "2024.2"
NG_MODE = False

# %% [markdown]
# Download the example PCB data.

# %%
temp_folder = tempfile.TemporaryDirectory(suffix=".ansys")
file_edb = download_file(source="edb/ANSYS-HSD_V1.aedb", destination=temp_folder.name)

# %% [markdown]
# ## Load example layout

# %%
edbapp = Edb(file_edb, edbversion=AEDT_VERSION)
# Out:
# PyAEDT INFO: Logger is initialized in EDB.
# PyAEDT INFO: legacy v0.38.dev0
# PyAEDT INFO: Python version 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]
# PyAEDT INFO: Database ANSYS-HSD_V1.aedb Opened in 2024.2
# PyAEDT INFO: Cell main Opened
# PyAEDT INFO: Builder was initialized.
# PyAEDT INFO: EDB initialized.

# %% [markdown]
# ## Create an empty dictionary to host all configurations

# %%
cfg = dict()

# %% [markdown]
# ## Add a circuit port between two nets

# %% [markdown]
# Keywords
#
# - **name**. Name of the port.
# - **Reference_designator**. Reference designator of the component.
# - **type**. Type of the port. Supported types are 'circuit', 'coax'
# - **positive_terminal**. Positive terminal of the port. Supported types are 'net', 'pin', 'pin_group', 'coordinates'
# - **negative_terminal**. Negative terminal of the port. Supported types are 'net', 'pin', 'pin_group', 'coordinates',
# 'nearest_pin'

# %%
port_1 = {
    "name": "port_1",
    "reference_designator": "X1",
    "type": "circuit",
    "positive_terminal": {"net": "PCIe_Gen4_TX2_N"},
    "negative_terminal": {"net": "GND"},
}

# %% [markdown]
# ## Add a circuit port between two pins

# %%
port_2 = {
    "name": "port_2",
    "reference_designator": "C375",
    "type": "circuit",
    "positive_terminal": {"pin": "1"},
    "negative_terminal": {"pin": "2"},
}

# %% [markdown]
# ## Add a circuit port between two pin groups

# %%
pin_groups = [
    {"name": "U9_5V_1", "reference_designator": "U9", "pins": ["32", "33"]},
    {"name": "U9_GND", "reference_designator": "U9", "net": "GND"},
]

# %%
port_3 = {
    "name": "port_3",
    "type": "circuit",
    "positive_terminal": {"pin_group": "U9_5V_1"},
    "negative_terminal": {"pin_group": "U9_GND"},
}

# %% [markdown]
# ## Add a circuit port between two coordinates

# %% [markdown]
# Keywords
#
# - **layer**. Layer on which the terminal is placed
# - **point**. XY coordinate the terminal is placed
# - **net**. Name of the net the terminal is placed on

# %%
port_4 = {
    "name": "port_4",
    "type": "circuit",
    "positive_terminal": {"coordinates": {"layer": "1_Top", "point": ["104mm", "37mm"], "net": "AVCC_1V3"}},
    "negative_terminal": {"coordinates": {"layer": "Inner6(GND2)", "point": ["104mm", "37mm"], "net": "GND"}},
}

# %% [markdown]
# ## Add a coax port

# %%
port_5 = {"name": "port_5", "reference_designator": "U1", "type": "coax", "positive_terminal": {"pin": "AM17"}}

# %% [markdown]
# ## Add a port reference to the nearest pin

# %% [markdown]
# Keywords
#
# - **reference_net**. Name of the reference net
# - **search_radius**. Reference pin search radius in meter

# %%
port_6 = {
    "name": "port_6",
    "reference_designator": "U15",
    "type": "circuit",
    "positive_terminal": {"pin": "D7"},
    "negative_terminal": {"nearest_pin": {"reference_net": "GND", "search_radius": 5e-3}},
}

# %% [markdown]
# ## Add distributed ports

# %% [markdown]
# Keywords
#
# - **distributed**. Whether to create distributed ports. When set to True, ports are created per pin

# %%
ports_distributed = {
    "name": "ports_d",
    "reference_designator": "U7",
    "type": "circuit",
    "distributed": True,
    "positive_terminal": {"net": "VDD_DDR"},
    "negative_terminal": {"net": "GND"},
}

# %% [markdown]
# ## Add setups in configuration

# %%
cfg["pin_groups"] = pin_groups
cfg["ports"] = [port_1, port_2, port_3, port_4, port_5, port_6, ports_distributed]

# %% [markdown]
# ## Write configuration into as json file

# %%
file_json = Path(temp_folder.name) / "edb_configuration.json"
with open(file_json, "w") as f:
    json.dump(cfg, f, indent=4, ensure_ascii=False)

# %% [markdown]
# ## Import configuration into example layout

# %%
edbapp.configuration.load(config_file=file_json)
edbapp.configuration.run()
# Out:
# True

# %% [markdown]
# ## Review

# %%
edbapp.ports
# Out:
# {'port_1': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b3e553ee0>,
#  'port_2': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b3c8eb4c0>,
#  'port_3': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae5870>,
#  'port_4': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae77c0>,
#  'port_5': <pyedb.dotnet.edb_core.edb_data.ports.CoaxPort at 0x21b24ae5b40>,
#  'port_6': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae6410>,
#  'U7_VDD_DDR_T9': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae7f70>,
#  'U7_VDD_DDR_R1': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae7760>,
#  'U7_VDD_DDR_L9': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae59f0>,
#  'U7_VDD_DDR_L1': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae7700>,
#  'U7_VDD_DDR_J9': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae7670>,
#  'U7_VDD_DDR_J8': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae7160>,
#  'U7_VDD_DDR_J2': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae74f0>,
#  'U7_VDD_DDR_J1': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae75b0>,
#  'U7_VDD_DDR_G9': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae7550>,
#  'U7_VDD_DDR_G7': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae74c0>,
#  'U7_VDD_DDR_G1': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae7460>,
#  'U7_VDD_DDR_F8': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae7430>,
#  'U7_VDD_DDR_F2': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae73d0>,
#  'U7_VDD_DDR_D9': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae7340>,
#  'U7_VDD_DDR_D1': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae72e0>,
#  'U7_VDD_DDR_C1': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae7280>,
#  'U7_VDD_DDR_B9': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae7220>,
#  'U7_VDD_DDR_B3': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae71c0>,
#  'U7_VDD_DDR_A9': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae7130>,
#  'U7_VDD_DDR_A1': <pyedb.dotnet.edb_core.edb_data.ports.CircuitPort at 0x21b24ae6b90>}

# %% [markdown]
# ## Save and close Edb
# The temporary folder will be deleted once the execution of this script is finished. Replace **edbapp.save()** with
# **edbapp.save_as("C:/example.aedb")** to keep the example project.

# %%
edbapp.save()
edbapp.close()
# Out:
# True
